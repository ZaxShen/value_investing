# %%
import akshare as ak
import pandas as pd
import datetime

# %%
# Out:
# 0it [00:00, ?it/s]

# %%
# Get the list of industry names
stock_board_industry_name_em_arr = ak.stock_board_industry_name_em()["板块名称"]
# Extract all stocks from the industry board
industry_stocks_df = pd.DataFrame(columns=["行业", "代码", "名称"])
for industry_name in stock_board_industry_name_em_arr:
    stock_board_industry_cons_em_df = ak.stock_board_industry_cons_em(symbol=industry_name)
    for row in stock_board_industry_cons_em_df.itertuples():
        industry_stocks_df.loc[len(industry_stocks_df)] = [
            industry_name,
            row.代码,
            row.名称
        ]
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
industry_stocks_df
# Out:
#         行业      代码    名称
# 0     能源金属  002192  融捷股份
# 1     能源金属  300390  天华新能
# 2     能源金属  002667  威领股份
# 3     能源金属  002466  天齐锂业
# 4     能源金属  002460  赣锋锂业
# ...    ...     ...   ...
# 5494  多元金融  603123  翠微股份
# 5495  多元金融  000617  中油资本
# 5496  多元金融  600927  永安期货
# 5497  多元金融  001236  弘业期货
# 5498  多元金融  603093  南华期货
#
# [5499 rows x 3 columns]

# %%
industry_stocks_df[industry_stocks_df["代码"] == "000554"]
# Out:
#        行业      代码    名称
# 514  石油行业  000554  泰山石油

# %%
industry_stocks_df["行业"].unique()
# Out:
# array(['能源金属', '贵金属', '电力行业', '电网设备', '银行', '汽车服务', '电机', '塑料制品', '公用事业',
#        '专业服务', '电源设备', '石油行业', '化学制药', '仪器仪表', '通用设备', '航天航空', '家电行业',
#        '交运设备', '造纸印刷', '医药商业', '生物制品', '汽车零部件', '纺织服装', '中药', '铁路公路',
#        '橡胶制品', '专用设备', '工程机械', '有色金属', '化肥行业', '物流行业', '工程咨询服务', '燃气',
#        '工程建设', '非金属材料', '化学制品', '化学原料', '环保行业', '电子元件', '综合行业', '农药兽药',
#        '航运港口', '化纤行业', '航空机场', '消费电子', '医疗器械', '水泥建材', '钢铁行业', '采掘行业',
#        '食品饮料', '家用轻工', '风电设备', '电池', '装修建材', '包装材料', '通信设备', '珠宝首饰',
#        '光学光电子', '农牧饲渔', '保险', '贸易行业', '医疗服务', '计算机设备', '装修装饰', '光伏设备',
#        '旅游酒店', '汽车整车', '美容护理', '房地产服务', '半导体', '船舶制造', '小金属', '商业百货',
#        '煤炭行业', '电子化学品', '酿酒行业', '玻璃玻纤', '互联网服务', '证券', '教育', '通信服务',
#        '房地产开发', '软件开发', '文化传媒', '游戏', '多元金融'], dtype=object)

# %%
industry_stocks_df["行业"].nunique()
# Out:
# 86
