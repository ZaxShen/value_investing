# %%
SHEET_ID = "1K-lLA1y8Ry19XvTay0Za6XtC_WWlRMLQ7ZZS4IZgD9E"
SHEET_NAME = "Metal"
API_KEY = "AIzaSyBRUZhqBoGnrMOSCv3BOt9UKlfJNfS_Rts"
SHEET_URL = f"https://sheets.googleapis.com/v4/spreadsheets/{SHEET_ID}/values/{SHEET_NAME}!A1:Z?alt=json&key={API_KEY}"

# %%
import pandas as pd

url = f"https://docs.google.com/spreadsheets/d/{SHEET_ID}/export?format=csv"

df = pd.read_csv(url)

df
# Out:
#           Name                                        Description      Code  \
# 0     Aluminum  Lightweight, corrosion-resistant metal widely ...  LMAHDS03
# 1       Copper  Highly conductive metal essential for electric...       HG1
# 2         Lead  Dense metal commonly used in batteries, radiat...       NaN
# 3         Zinc  Metal primarily used for galvanizing steel to ...       NaN
# 4       Nickel  Corrosion-resistant metal used in stainless st...       NaN
# 5          Tin  Soft, malleable metal often used as a protecti...       NaN
# 6     Chromium  Hard metal known for its high resistance to ta...       NaN
# 7    Manganese  Brittle metal used to improve strength and har...       NaN
# 8    Magnesium  Lightweight metal with high strength-to-weight...       NaN
# 9     Titanium  Strong, corrosion-resistant metal used in aero...       NaN
# 10      Cobalt  Hard, lustrous metal used in batteries, supera...       NaN
# ...

# %%
df[df.Code.notna()]
# Out:
#          Name                                        Description      Code  \
# 0    Aluminum  Lightweight, corrosion-resistant metal widely ...  LMAHDS03
# 1      Copper  Highly conductive metal essential for electric...       HG1
# 11    Lithium  Lightest metal, crucial for rechargeable batte...        LC
# 20      Steel  An alloy primarily of iron and carbon, used in...       JBP
# 21    Uranium  Fuel for nuclear power plants, medical isotope...       UXA
# 22  Palladium  Used in catalytic converters, fuel cells, and ...   XPD/USD
# 23   Platinum  Used in automotive, chemical refining, jewelry...   XPT/USD
#
#        Type
# 0   Futures
# 1   Futures
# 11  Futures
# 20  Futures
# 21  Futures
# 22     Spot
# 23     Spot
